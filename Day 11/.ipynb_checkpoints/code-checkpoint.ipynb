# %% [markdown]
# FUNCTION TO PARSE DATA

# %%
def parse(filename) :
    ans = []
    with open(filename,"r") as f :
        #edit here 
        ans.append(1)

    return ans

# %%
data = parse("test.txt")
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[3], line 1
# ----> 1 data = parse("test.txt")
#
# Cell In[2], line 5, in parse(filename)
#       2 ans = []
#       3 with open(filename,"r") as f :
#       4     #edit here
# ----> 5     ans.push(1)
#       7 return ans
#
# AttributeError: 'list' object has no attribute 'push'
