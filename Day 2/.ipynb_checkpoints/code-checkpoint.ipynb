# %% [markdown]
# FUNCTION TO PARSE DATA

# %%
def parse(filename) :
    ans = []
    with open(filename,"r") as f :
        #edit here 
        ans.append(1)

    return ans

# %% [markdown]
# PART ONE

# %%
data = parse("test.txt")

# %% [markdown]
# PART TWO

# %%
data = parse("test.txt")
